# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\\Users\Prateek\\Downloads\\New folder\\t20.csv')

# %%
df
# Out:
#       Unnamed: 0                  Player       Span  Mat Inns  NO  Runs   HS  \
# 0              0         V Kohli (INDIA)  2010-2019   75   70  20  2633  94*
# 1              1       RG Sharma (INDIA)  2007-2019  104   96  14  2633  118
# 2              2         MJ Guptill (NZ)  2009-2019   83   80   7  2436  105
# 3              3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263   75
# 4              4        BB McCullum (NZ)  2005-2015   71   70  10  2140  123
# ...          ...                     ...        ...  ...  ...  ..   ...  ...
# 2001           1   SG Whittingham (SCOT)  2018-2018    3    -   -     -    -
# 2002           2        LJ Woodcock (NZ)  2010-2011    3    -   -     -    -
# 2003           3        Zamir Khan (AFG)  2012-2012    1    -   -     -    -
# 2004           4          S Zargar (Mex)  2019-2019    1    -   -     -    -
# 2005           5      Ziaur Rahman (AFG)  2019-2019    1    -   -     -    -
#
# ...

# %%
df.head(20)
# Out:
#     Unnamed: 0                  Player       Span  Mat Inns  NO  Runs    HS  \
# 0            0         V Kohli (INDIA)  2010-2019   75   70  20  2633   94*
# 1            1       RG Sharma (INDIA)  2007-2019  104   96  14  2633   118
# 2            2         MJ Guptill (NZ)  2009-2019   83   80   7  2436   105
# 3            3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263    75
# 4            4        BB McCullum (NZ)  2005-2015   71   70  10  2140   123
# 5            5         DA Warner (AUS)  2009-2019   76   76   8  2079  100*
# 6            6        EJG Morgan (ENG)  2009-2019   86   84  17  2002    91
# 7            7  Mohammad Shahzad (AFG)  2010-2018   65   65   3  1936  118*
# 8            8          JP Duminy (SA)  2007-2019   81   75  25  1934   96*
# 9            9       PR Stirling (IRE)  2009-2019   72   71   6  1929    91
# 10          10   Mohammad Hafeez (PAK)  2006-2018   89   86   8  1908    86
# ...

# %%
df.tail()
# Out:
#      #Player#Span#Mat#Inns#NO#Runs#HS#Ave#BF#SR#100#50#0#4s#6s
# 2001  1#SG Whittingham (SCOT)#2018-2018#3#-#-#-#-#-#...
# 2002  2#LJ Woodcock (NZ)#2010-2011#3#-#-#-#-#-#-#-#-...
# 2003  3#Zamir Khan (AFG)#2012-2012#1#-#-#-#-#-#-#-#-...
# 2004  4#S Zargar (Mex)#2019-2019#1#-#-#-#-#-#-#-#-#-...
# 2005  5#Ziaur Rahman (AFG)#2019-2019#1#-#-#-#-#-#-#-...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df.head()

# %%
df1.to_csv("test.csv")

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C84B-264E
#
#  Directory of C:\Users\Prateek\Desktop\Pandas
#
# 30-10-2022  10:52 AM    <DIR>          .
# 30-10-2022  10:52 AM    <DIR>          ..
# 22-10-2022  12:15 PM    <DIR>          .ipynb_checkpoints
# 30-10-2022  10:52 AM            39,991 Introduction to Pandas.ipynb
# 30-10-2022  10:54 AM               486 test.csv
#                2 File(s)         40,477 bytes
#                3 Dir(s)  32,535,269,376 bytes free

# %%
pd.read_csv("test.csv")
# Out:
#    Unnamed: 0  Unnamed: 0.1                  Player       Span  Mat  Inns  NO  \
# 0           0             0         V Kohli (INDIA)  2010-2019   75    70  20
# 1           1             1       RG Sharma (INDIA)  2007-2019  104    96  14
# 2           2             2         MJ Guptill (NZ)  2009-2019   83    80   7
# 3           3             3  Shoaib Malik (ICC/PAK)  2006-2019  111   104  30
# 4           4             4        BB McCullum (NZ)  2005-2015   71    70  10
#
#    Runs   HS    Ave    BF      SR  100  50  0   4s   6s
# 0  2633  94*  52.66  1907  138.07    0  24  2  247   71
# 1  2633  118  32.10  1905  138.21    4  19  6  234  120
# 2  2436  105  33.36  1810  134.58    2  15  2  215  113
# 3  2263   75  30.58  1824  124.06    0   7  1  186   61
# 4  2140  123  35.66  1571  136.21    2  13  3  199   91

# %%
df=pd.read_csv(r'C:\\Users\Prateek\\Downloads\\New folder\\t20.csv')

# %%
df
# Out:
#       Unnamed: 0                  Player       Span  Mat Inns  NO  Runs   HS  \
# 0              0         V Kohli (INDIA)  2010-2019   75   70  20  2633  94*
# 1              1       RG Sharma (INDIA)  2007-2019  104   96  14  2633  118
# 2              2         MJ Guptill (NZ)  2009-2019   83   80   7  2436  105
# 3              3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263   75
# 4              4        BB McCullum (NZ)  2005-2015   71   70  10  2140  123
# ...          ...                     ...        ...  ...  ...  ..   ...  ...
# 2001           1   SG Whittingham (SCOT)  2018-2018    3    -   -     -    -
# 2002           2        LJ Woodcock (NZ)  2010-2011    3    -   -     -    -
# 2003           3        Zamir Khan (AFG)  2012-2012    1    -   -     -    -
# 2004           4          S Zargar (Mex)  2019-2019    1    -   -     -    -
# 2005           5      Ziaur Rahman (AFG)  2019-2019    1    -   -     -    -
#
# ...

# %%
df=pd.read_csv(r'C:\\Users\Prateek\\Downloads\\New folder\\t20.csv',sep='#')

# %%
df
# Out:
#       Unnamed: 0                  Player       Span  Mat Inns  NO  Runs   HS  \
# 0              0         V Kohli (INDIA)  2010-2019   75   70  20  2633  94*
# 1              1       RG Sharma (INDIA)  2007-2019  104   96  14  2633  118
# 2              2         MJ Guptill (NZ)  2009-2019   83   80   7  2436  105
# 3              3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263   75
# 4              4        BB McCullum (NZ)  2005-2015   71   70  10  2140  123
# ...          ...                     ...        ...  ...  ...  ..   ...  ...
# 2001           1   SG Whittingham (SCOT)  2018-2018    3    -   -     -    -
# 2002           2        LJ Woodcock (NZ)  2010-2011    3    -   -     -    -
# 2003           3        Zamir Khan (AFG)  2012-2012    1    -   -     -    -
# 2004           4          S Zargar (Mex)  2019-2019    1    -   -     -    -
# 2005           5      Ziaur Rahman (AFG)  2019-2019    1    -   -     -    -
#
# ...

# %%
df=pd.read_csv(r'C:\\Users\Prateek\\Downloads\\New folder\\t20.csv',sep='#',header=None)    #hide your header

# %%
df
# Out:
#        0                       1          2    3     4   5     6    7      8   \
# 0     NaN                  Player       Span  Mat  Inns  NO  Runs   HS    Ave
# 1     0.0         V Kohli (INDIA)  2010-2019   75    70  20  2633  94*  52.66
# 2     1.0       RG Sharma (INDIA)  2007-2019  104    96  14  2633  118   32.1
# 3     2.0         MJ Guptill (NZ)  2009-2019   83    80   7  2436  105  33.36
# 4     3.0  Shoaib Malik (ICC/PAK)  2006-2019  111   104  30  2263   75  30.58
# ...   ...                     ...        ...  ...   ...  ..   ...  ...    ...
# 2002  1.0   SG Whittingham (SCOT)  2018-2018    3     -   -     -    -      -
# 2003  2.0        LJ Woodcock (NZ)  2010-2011    3     -   -     -    -      -
# 2004  3.0        Zamir Khan (AFG)  2012-2012    1     -   -     -    -      -
# 2005  4.0          S Zargar (Mex)  2019-2019    1     -   -     -    -      -
# 2006  5.0      Ziaur Rahman (AFG)  2019-2019    1     -   -     -    -      -
#
# ...

# %%
df=pd.read_csv(r'C:\\Users\Prateek\\Downloads\\New folder\\t20.csv',sep='#',header=None,names=['a','b','c','d','e','f','g','h'])   #you should menction your name

# %%
df
# Out:
#                                                                a     b  \
# NaN Player                 Span      Mat Inns NO Runs HS     Ave    BF
# 0.0 V Kohli (INDIA)        2010-2019 75  70   20 2633 94*  52.66  1907
# 1.0 RG Sharma (INDIA)      2007-2019 104 96   14 2633 118   32.1  1905
# 2.0 MJ Guptill (NZ)        2009-2019 83  80   7  2436 105  33.36  1810
# 3.0 Shoaib Malik (ICC/PAK) 2006-2019 111 104  30 2263 75   30.58  1824
# ...                                                          ...   ...
# 1.0 SG Whittingham (SCOT)  2018-2018 3   -    -  -    -        -     -
# 2.0 LJ Woodcock (NZ)       2010-2011 3   -    -  -    -        -     -
# 3.0 Zamir Khan (AFG)       2012-2012 1   -    -  -    -        -     -
# 4.0 S Zargar (Mex)         2019-2019 1   -    -  -    -        -     -
# 5.0 Ziaur Rahman (AFG)     2019-2019 1   -    -  -    -        -     -
#
#                                                                 c    d   e  f  \
# ...

# %%
df=pd.read_csv(r'C:\\Users\Prateek\\Downloads\\New folder\\t20.csv',sep='#',header=None,names=['a','b','c','d','e','f','g','h'],skiprows=[0,4,6,8])

# %%
df
# Out:
#                                                           a     b       c  d  \
# 0 V Kohli (INDIA)       2010-2019 75  70 20 2633 94*  52.66  1907  138.07  0
# 1 RG Sharma (INDIA)     2007-2019 104 96 14 2633 118   32.1  1905  138.21  4
# 2 MJ Guptill (NZ)       2009-2019 83  80 7  2436 105  33.36  1810  134.58  2
# 4 BB McCullum (NZ)      2005-2015 71  70 10 2140 123  35.66  1571  136.21  2
# 6 EJG Morgan (ENG)      2009-2019 86  84 17 2002 91   29.88  1475  135.72  0
# ...                                                     ...   ...     ... ..
# 1 SG Whittingham (SCOT) 2018-2018 3   -  -  -    -        -     -       -  -
# 2 LJ Woodcock (NZ)      2010-2011 3   -  -  -    -        -     -       -  -
# 3 Zamir Khan (AFG)      2012-2012 1   -  -  -    -        -     -       -  -
# 4 S Zargar (Mex)        2019-2019 1   -  -  -    -        -     -       -  -
# 5 Ziaur Rahman (AFG)    2019-2019 1   -  -  -    -        -     -       -  -
#
# ...

# %%
df=pd.read_csv(r'C:\\Users\Prateek\\Downloads\\New folder\\t20.csv',sep='#',na_values=['V Kohli (INDIA)','RG Sharma (INDIA)'])    # na_values show NAN value if you show the any name

# %%
df
# Out:
#       Unnamed: 0                  Player       Span  Mat Inns  NO  Runs   HS  \
# 0              0                     NaN  2010-2019   75   70  20  2633  94*
# 1              1                     NaN  2007-2019  104   96  14  2633  118
# 2              2         MJ Guptill (NZ)  2009-2019   83   80   7  2436  105
# 3              3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263   75
# 4              4        BB McCullum (NZ)  2005-2015   71   70  10  2140  123
# ...          ...                     ...        ...  ...  ...  ..   ...  ...
# 2001           1   SG Whittingham (SCOT)  2018-2018    3    -   -     -    -
# 2002           2        LJ Woodcock (NZ)  2010-2011    3    -   -     -    -
# 2003           3        Zamir Khan (AFG)  2012-2012    1    -   -     -    -
# 2004           4          S Zargar (Mex)  2019-2019    1    -   -     -    -
# 2005           5      Ziaur Rahman (AFG)  2019-2019    1    -   -     -    -
#
# ...

# %%
df1=pd.read_csv(r'C:\\Users\Prateek\\Downloads\\New folder\\t20.csv',sep='#',skiprows=[0,1,2])

# %%
df1
# Out:
#       2         MJ Guptill (NZ)  2009-2019   83   80   7  2436   105  33.36  \
# 0     3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263    75  30.58
# 1     4        BB McCullum (NZ)  2005-2015   71   70  10  2140   123  35.66
# 2     5         DA Warner (AUS)  2009-2019   76   76   8  2079  100*  30.57
# 3     6        EJG Morgan (ENG)  2009-2019   86   84  17  2002    91  29.88
# 4     7  Mohammad Shahzad (AFG)  2010-2018   65   65   3  1936  118*  31.22
# ...  ..                     ...        ...  ...  ...  ..   ...   ...    ...
# 1998  1   SG Whittingham (SCOT)  2018-2018    3    -   -     -     -      -
# 1999  2        LJ Woodcock (NZ)  2010-2011    3    -   -     -     -      -
# 2000  3        Zamir Khan (AFG)  2012-2012    1    -   -     -     -      -
# 2001  4          S Zargar (Mex)  2019-2019    1    -   -     -     -      -
# 2002  5      Ziaur Rahman (AFG)  2019-2019    1    -   -     -     -      -
#
#       1810  134.58 2.1  15 2.2  215 113
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#        #Player#Span#Mat#Inns#NO#Runs#HS#Ave#BF#SR#100#50#0#4s#6s
# count                                                2006
# unique                                               2006
# top     0#V Kohli (INDIA)#2010-2019#75#70#20#2633#94*#...
# freq                                                    1

# %%
df.dtypes
# Out:
# #Player#Span#Mat#Inns#NO#Runs#HS#Ave#BF#SR#100#50#0#4s#6s    object
# dtype: object

# %%
df1.dtypes
# Out:
# 2                   int64
# MJ Guptill (NZ)    object
# 2009-2019          object
# 83                  int64
# 80                 object
# 7                  object
# 2436               object
# 105                object
# 33.36              object
# 1810               object
# 134.58             object
# 2.1                object
# 15                 object
# 2.2                object
# 215                object
# 113                object
# dtype: object

# %%
df.head()
# Out:
#   #Player#Span#Mat#Inns#NO#Runs#HS#Ave#BF#SR#100#50#0#4s#6s
# 0  0#V Kohli (INDIA)#2010-2019#75#70#20#2633#94*#...
# 1  1#RG Sharma (INDIA)#2007-2019#104#96#14#2633#1...
# 2  2#MJ Guptill (NZ)#2009-2019#83#80#7#2436#105#3...
# 3  3#Shoaib Malik (ICC/PAK)#2006-2019#111#104#30#...
# 4  4#BB McCullum (NZ)#2005-2015#71#70#10#2140#123...

# %%
df1.to_csv("result.csv")   #stored your data in notebook

# %%
df1.to_csv("result1.csv",index=False,header=False)

# %%
df1.to_csv("result2.csv",index=False,header=False,sep ="#")    # you should use comma seprator as per data "# ,"

# %%
df1.to_csv("result3.csv",index=False,sep = "#",columns=['MJ Guptill (NZ)','2009-2019'])

# %%
df1
# Out:
#       2         MJ Guptill (NZ)  2009-2019   83   80   7  2436   105  33.36  \
# 0     3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263    75  30.58
# 1     4        BB McCullum (NZ)  2005-2015   71   70  10  2140   123  35.66
# 2     5         DA Warner (AUS)  2009-2019   76   76   8  2079  100*  30.57
# 3     6        EJG Morgan (ENG)  2009-2019   86   84  17  2002    91  29.88
# 4     7  Mohammad Shahzad (AFG)  2010-2018   65   65   3  1936  118*  31.22
# ...  ..                     ...        ...  ...  ...  ..   ...   ...    ...
# 1998  1   SG Whittingham (SCOT)  2018-2018    3    -   -     -     -      -
# 1999  2        LJ Woodcock (NZ)  2010-2011    3    -   -     -     -      -
# 2000  3        Zamir Khan (AFG)  2012-2012    1    -   -     -     -      -
# 2001  4          S Zargar (Mex)  2019-2019    1    -   -     -     -      -
# 2002  5      Ziaur Rahman (AFG)  2019-2019    1    -   -     -     -      -
#
#       1810  134.58 2.1  15 2.2  215 113
# ...

# %%
df=pd.read_csv(r'C:\\Users\Prateek\\Downloads\\New folder\\t20.csv',sep='#')

# %%
df
# Out:
#       Unnamed: 0                  Player       Span  Mat Inns  NO  Runs   HS  \
# 0              0         V Kohli (INDIA)  2010-2019   75   70  20  2633  94*
# 1              1       RG Sharma (INDIA)  2007-2019  104   96  14  2633  118
# 2              2         MJ Guptill (NZ)  2009-2019   83   80   7  2436  105
# 3              3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263   75
# 4              4        BB McCullum (NZ)  2005-2015   71   70  10  2140  123
# ...          ...                     ...        ...  ...  ...  ..   ...  ...
# 2001           1   SG Whittingham (SCOT)  2018-2018    3    -   -     -    -
# 2002           2        LJ Woodcock (NZ)  2010-2011    3    -   -     -    -
# 2003           3        Zamir Khan (AFG)  2012-2012    1    -   -     -    -
# 2004           4          S Zargar (Mex)  2019-2019    1    -   -     -    -
# 2005           5      Ziaur Rahman (AFG)  2019-2019    1    -   -     -    -
#
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0                 Player       Span  Mat Inns NO Runs HS Ave  \
# 2001           1  SG Whittingham (SCOT)  2018-2018    3    -  -    -  -   -
# 2002           2       LJ Woodcock (NZ)  2010-2011    3    -  -    -  -   -
# 2003           3       Zamir Khan (AFG)  2012-2012    1    -  -    -  -   -
# 2004           4         S Zargar (Mex)  2019-2019    1    -  -    -  -   -
# 2005           5     Ziaur Rahman (AFG)  2019-2019    1    -  -    -  -   -
#
#      BF SR 100 50  0 4s 6s
# 2001  -  -   -  -  -  -  -
# 2002  -  -   -  -  -  -  -
# 2003  -  -   -  -  -  -  -
# 2004  -  -   -  -  -  -  -
# 2005  -  -   -  -  -  -  -

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS',
#        'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
df['Player']   #
# Out:
# 0              V Kohli (INDIA)
# 1            RG Sharma (INDIA)
# 2              MJ Guptill (NZ)
# 3       Shoaib Malik (ICC/PAK)
# 4             BB McCullum (NZ)
#                  ...
# 2001     SG Whittingham (SCOT)
# 2002          LJ Woodcock (NZ)
# 2003          Zamir Khan (AFG)
# 2004            S Zargar (Mex)
# 2005        Ziaur Rahman (AFG)
# Name: Player, Length: 2006, dtype: object

# %%
type(df['Player'])     #if you going pass only one column name it is called series
# Out:
# pandas.core.series.Series

# %%
df[['Player']]
# Out:
#                       Player
# 0            V Kohli (INDIA)
# 1          RG Sharma (INDIA)
# 2            MJ Guptill (NZ)
# 3     Shoaib Malik (ICC/PAK)
# 4           BB McCullum (NZ)
# ...                      ...
# 2001   SG Whittingham (SCOT)
# 2002        LJ Woodcock (NZ)
# 2003        Zamir Khan (AFG)
# 2004          S Zargar (Mex)
# 2005      Ziaur Rahman (AFG)
#
# [2006 rows x 1 columns]

# %%
type(df[['Player']])   #if you pass your column name in a form of list it is dataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Player','Span']]            # you have to use multiple column data
# Out:
#                       Player       Span
# 0            V Kohli (INDIA)  2010-2019
# 1          RG Sharma (INDIA)  2007-2019
# 2            MJ Guptill (NZ)  2009-2019
# 3     Shoaib Malik (ICC/PAK)  2006-2019
# 4           BB McCullum (NZ)  2005-2015
# ...                      ...        ...
# 2001   SG Whittingham (SCOT)  2018-2018
# 2002        LJ Woodcock (NZ)  2010-2011
# 2003        Zamir Khan (AFG)  2012-2012
# 2004          S Zargar (Mex)  2019-2019
# 2005      Ziaur Rahman (AFG)  2019-2019
#
# [2006 rows x 2 columns]

# %%
df[['Unnamed: 0','Player','Span']]           # you have to use multiple column data
# Out:
#       Unnamed: 0                  Player       Span
# 0              0         V Kohli (INDIA)  2010-2019
# 1              1       RG Sharma (INDIA)  2007-2019
# 2              2         MJ Guptill (NZ)  2009-2019
# 3              3  Shoaib Malik (ICC/PAK)  2006-2019
# 4              4        BB McCullum (NZ)  2005-2015
# ...          ...                     ...        ...
# 2001           1   SG Whittingham (SCOT)  2018-2018
# 2002           2        LJ Woodcock (NZ)  2010-2011
# 2003           3        Zamir Khan (AFG)  2012-2012
# 2004           4          S Zargar (Mex)  2019-2019
# 2005           5      Ziaur Rahman (AFG)  2019-2019
#
# [2006 rows x 3 columns]

# %%
dt=pd.read_excel(r'C:\Users\Prateek\Downloads\airline1.xlsx')

# %%
dt
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
dt=pd.read_excel(r'C:\Users\Prateek\Downloads\airline1.xlsx',sheet_name='alcohol_data')

# %%
dt
# Out:
#      A  K     X  Y
# 0    2  2   758  1
# 1    2  3  1785  1
# 2    3  0  1200  1
# 3    1  0   545  1
# 4    4  1   547  1
# ..  .. ..   ... ..
# 995  2  3   704  1
# 996  2  0   822  1
# 997  2  0  1383  1
# 998  2  2   816  0
# 999  2  2   387  0
#
# [1000 rows x 4 columns]

# %%
# sf=pd.read_excel(r'‪C:\Users\Prateek\Downloads\sales.xlsx')

# %%
df4=pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool')

# %%
type(df4)
# Out:
# list

# %%
len(df4)
# Out:
# 7

# %%
df4[3]
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS       MP      FG     FGA  \
# 0     2009-10  20.0  OKC  NBA   PF   73.0    0.0   1323.0   201.0   370.0
# 1     2010-11  21.0  OKC  NBA   PF   82.0   44.0   2216.0   335.0   617.0
# 2     2011-12  22.0  OKC  NBA   PF   66.0   66.0   1792.0   262.0   490.0
# 3     2012-13  23.0  OKC  NBA   PF   80.0   80.0   2486.0   446.0   778.0
# 4     2013-14  24.0  OKC  NBA   PF   81.0   81.0   2666.0   524.0   978.0
# 5     2014-15  25.0  OKC  NBA   PF   64.0   64.0   2116.0   374.0   786.0
# 6     2015-16  26.0  OKC  NBA   PF   78.0   78.0   2500.0   416.0   869.0
# 7     2016-17  27.0  TOT  NBA   PF   79.0   79.0   2422.0   471.0   982.0
# 8     2016-17  27.0  ORL  NBA   PF   56.0   56.0   1710.0   343.0   703.0
# 9     2016-17  27.0  TOR  NBA   PF   23.0   23.0    712.0   128.0   279.0
# 10    2017-18  28.0  TOR  NBA   PF   76.0   76.0   2093.0   379.0   784.0
# 11    2018-19  29.0  TOR  NBA    C   74.0   51.0   2010.0   464.0   877.0
# ...

# %%
df4[3].to_csv("players_data.csv")     #you have to stored your this data in your destop system

# %%
html_data = pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool')
for i in range(len(html_data)):
    html_data[i].to_csv(f"html_data{i}.csv",index=False)

# %%
html_data
# Out:
# [  Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Per 36 Minutes  \
#                Season                Age                 Lg             FG
#  0            2022-23                 33                NBA            6.6
#
#                                    ...                                Shooting  \
#      FGA   3P  3PA   FT  FTA  ORB  ...  AST  STL  BLK  TOV   PF   PTS      FG%
#  0  13.3  1.5  4.3  1.6  2.2  2.5  ...  2.3  0.5  1.4  1.9  3.7  16.3    0.496
#
#                 Unnamed: 20_level_0
#      3P%    FT%               WS/48
#  0  0.36  0.751               0.125
#
#  [1 rows x 21 columns],
#         Season   Age                                     Tm  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = """{
"name" :"prateek",
"phone_no" :"4541255",
"comp": ["iNeuron", "EY" , "unilver" , "verizon" , "deloitte" , "wipro"]
}
"""

# %%
eval(s)
# Out:
# {'name': 'prateek',
#  'phone_no': '4541255',
#  'comp': ['iNeuron', 'EY', 'unilver', 'verizon', 'deloitte', 'wipro']}

# %%
import json

# %%
json.loads(s)
# Out:
# {'name': 'prateek',
#  'phone_no': '4541255',
#  'comp': ['iNeuron', 'EY', 'unilver', 'verizon', 'deloitte', 'wipro']}

# %%
s1 = json.loads(s)

# %%
s1
# Out:
# {'name': 'prateek',
#  'phone_no': '4541255',
#  'comp': ['iNeuron', 'EY', 'unilver', 'verizon', 'deloitte', 'wipro']}

# %%
pd.DataFrame(s1)
# Out:
#       name phone_no      comp
# 0  prateek  4541255   iNeuron
# 1  prateek  4541255        EY
# 2  prateek  4541255   unilver
# 3  prateek  4541255   verizon
# 4  prateek  4541255  deloitte
# 5  prateek  4541255     wipro

# %%
pd.DataFrame(s1, columns=['comp'])
# Out:
#        comp
# 0   iNeuron
# 1        EY
# 2   unilver
# 3   verizon
# 4  deloitte
# 5     wipro

# %%
type(s)
# Out:
# str

# %%
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49434',
#   'id': 1430805131,
#   'node_id': 'I_kwDOAA0YD85VSFqL',
#   'number': 49434,
#   'title': 'DEPR:  Allowing grouping by an index label when there are duplicates',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
# ...

# %%
js = res.json()              #convert json as js

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49434',
#   'id': 1430805131,
#   'node_id': 'I_kwDOAA0YD85VSFqL',
#   'number': 49434,
#   'title': 'DEPR:  Allowing grouping by an index label when there are duplicates',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
# ...

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/49434',
#  'id': 1430805131,
#  'node_id': 'I_kwDOAA0YD85VSFqL',
#  'number': 49434,
#  'title': 'DEPR:  Allowing grouping by an index label when there are duplicates',
#  'user': {'login': 'rhshadrach',
#   'id': 45562402,
#   'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/rhshadrach',
#   'html_url': 'https://github.com/rhshadrach',
# ...

# %%
js[0]['title']
# Out:
# 'DEPR:  Allowing grouping by an index label when there are duplicates'

# %%
for i in range(len(js)):
     print(js[i]['title'])
# Out:
# DEPR:  Allowing grouping by an index label when there are duplicates
# BUILD:
# BUG: Series(mixed_tz_datetime_objs, dtype=dt64tz)
# DEPR: Remove df.info(null_counts=)
# DEPR: Enforce disallowed merging scenarios
# gh 94906
# enable pylint wildcard-import
# CLN: assorted
# enable pylint unused-wildcard-import
# TST: Remove unnecessary pytest fixture scopes
# CLN: test_nanops.py
# CLN: test_expressions.py
# API: replace casting dtype instead of converting NA value when replacing missing value with another missing value
# ENH: Add masked engine
# BUG: Unclear error message when merging tables and passing invalid option to validate
# issue 48855 enable pylint unnecessary-pass
# BUG: Unclear error message when merging tables and passing invalid option to validate
# API: make some Timestamp args keyword-only
# DEPR: non-keyword args, errors arg
# ENH: Clearer error messaging when pd.DataFrame.to_sql() receives an empty string for name param
# DEPR: indexing
# ...

# %%
len(js)
# Out:
# 30

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49434/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49434',
#   'id': 1430805131,
#   'node_id': 'I_kwDOAA0YD85VSFqL',
#   'number': 49434,
#   'title': 'DEPR:  Allowing grouping by an index label when there are duplicates',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
# ...

# %%
pd.DataFrame(js,columns=['url','title'])        #convert data into a tabluear format
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(js)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(js).head()     #give you only 5 records
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
df4 = pd.DataFrame(js)

# %%
df4.to_csv('json_dump.csv')

# %%
js[0]['user']
# Out:
# {'login': 'rhshadrach',
#  'id': 45562402,
#  'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/rhshadrach',
#  'html_url': 'https://github.com/rhshadrach',
#  'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#  'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#  'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#  'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#  'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#  'type': 'User',
# ...

# %%
l =[]
for i in range(len(js)):
    l.append(js[i]['user'])
    
pd.DataFrame(l)
# Out:
#            login         id               node_id  \
# 0     rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 1    BHARGAV2017   78274583  MDQ6VXNlcjc4Mjc0NTgz
# 2   jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 3      mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 4      mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5     ramvikrams  106332857          U_kgDOBlaCuQ
# 6      natmokval   91160475  MDQ6VXNlcjkxMTYwNDc1
# 7   jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 8      natmokval   91160475  MDQ6VXNlcjkxMTYwNDc1
# 9      mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 10     mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 11     mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 12         phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 13         phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 14       raisadz   34237447  MDQ6VXNlcjM0MjM3NDQ3
# 15     natmokval   91160475  MDQ6VXNlcjkxMTYwNDc1
# 16       raisadz   34237447  MDQ6VXNlcjM0MjM3NDQ3
# 17  jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# ...

# %%
user =[]
st = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
js=st.json()
for i in range(len(js)):
    user.append(js[i]['user'])
pd.DataFrame(user)
# Out:
#            login         id               node_id  \
# 0       jbcurtin      45219      MDQ6VXNlcjQ1MjE5
# 1     rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 2    BHARGAV2017   78274583  MDQ6VXNlcjc4Mjc0NTgz
# 3   jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 4      mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5      mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 6     ramvikrams  106332857          U_kgDOBlaCuQ
# 7      natmokval   91160475  MDQ6VXNlcjkxMTYwNDc1
# 8   jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 9      natmokval   91160475  MDQ6VXNlcjkxMTYwNDc1
# 10     mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 11     mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 12     mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 13         phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 14         phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 15       raisadz   34237447  MDQ6VXNlcjM0MjM3NDQ3
# 16     natmokval   91160475  MDQ6VXNlcjkxMTYwNDc1
# 17       raisadz   34237447  MDQ6VXNlcjM0MjM3NDQ3
# ...

# %%
# json_data = pd.read_json=("https://api.github.com/repos/pandas-dev/pandas/issues")
# ts=pd.DataFrame.from_records(json_data['user'])
# ts.head()
